# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from Function import *

video_path = "C:\\Users\\leonh\\Pictures\\BumS\\Projekt\\Videos\\muc_bhf_7.mp4"
frames = read_video_frames(video_path)
print(len(frames))

frames1 = frames[1000:1400]

img = frames1[375][1]
plt.imshow(img)
plt.axis('off')
plt.savefig('ausgabe.jpg', format='jpeg', dpi=300)
plt.show()
# Out:
# 2329

# %%
plt.gray()
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
i_img = 255- img_gray
t, seg = cv2.threshold(i_img, 155, 255, cv2.THRESH_BINARY)
plt.imshow(seg)
plt.axis('off')
plt.savefig('ausgabe.jpg', format='jpeg', dpi=300)
plt.show()

# %%
plt.axis('off')
plt.savefig('ausgabe.jpg', format='jpeg', dpi=300)
plt.show()
