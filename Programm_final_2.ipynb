# %%
import threading
import cv2
import pyaudio
import wave
import cv2
import numpy as np q
import matplotlib.pyplot as plt 
from tools_class_new import *
import sys
import time
import re

global_res_text = 0
global_previous_text = 0


# Video-Thread
def video_thread( video, line_color, total_frames):
    
    plt.gray()

    #video, line_color, total_frames = user_input()
    print(total_frames)

    # declare some list and start values which are needed
    save_cnts = 0
    wait = 0

    # init class/values for while loop
    direct = FindDirection()

    while video.isOpened():
        # Read a single frame
        ret, frame = video.read()
        if not ret:
            print("Error load frame")
            break
        
        #Create a Frame Object
        frame = FrameObject(frame)
        img = frame.img

        # Create Segmemtation Object  
        seg = Segmentation(frame, line_color)
        img_cont = seg.get_orientation_lines()

        frame.build_center_line(img_cont)
        img = frame.make_block_over_center_line()
        
        # Get Values from FrameObject to Direction Object
        direct.wait_for_complete_contour(img)
        direct.get_values_from_frame_object(frame)
        direct.find_nearest_line(img_cont)
        direct.check_where_to_go()
        res_text = direct.smooth_output()
        global global_res_text 
        global_res_text= res_text
        #check_last_direction_changed(res_text)
        frame.text_in_frame(res_text)
        #print(res_text)
        frame_show = frame.overlay_segmentation(img_cont)
        
        #direct.add_one_counter()
        cv2.imshow('Processed',frame_show)

        #time.sleep(0.0005)
        # Check for key press to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        if video.get(cv2.CAP_PROP_POS_FRAMES) == total_frames:
            break
    # Release the video objects and close the windows
    video.release()
    cv2.destroyAllWindows()


# Audio-Thread
def audio_thread():

    global global_res_text
    global globla_previous_text

    while video.isOpened():
        # Read a single frame
        ret, frame = video.read()
        if not ret:
            print("Error load frame")
            break
        
        # Überprüfen, ob sich das letzte Element geändert hat
        if global_res_text != global_previous_text:
            global_previous_text = global_res_text
            #print("audio_txt", previous_element)
            audio_output(global_previous_text)            #play_audio(previous_element)
        #else:
            #print("prev_txt", previous_element)
        time.sleep(0.01)

     # Check for key press to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        if video.get(cv2.CAP_PROP_POS_FRAMES) == total_frames:
            break
    # Release the video objects and close the windows
    video.release()
    cv2.destroyAllWindows()
 
video, line_color, total_frames = user_input()

# Threads starten
video_thread = threading.Thread(target=video_thread, args=(video, line_color, total_frames))
audio_thread = threading.Thread(target=audio_thread)

video_thread.start()
audio_thread.start()

video_thread.join()
audio_thread.join()
# Out:
# wrong path please try again
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "C:\Program Files\Python38\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\Python38\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_1920\2535406865.py", line 91, in audio_thread
# UnboundLocalError: local variable 'global_previous_text' referenced before assignment
# You did a great Job!
# 2329
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error

# %%
import threading
import cv2
import pyaudio
import wave
import cv2
import numpy as np 
import matplotlib.pyplot as plt 
from tools_class_new import *
import sys
import time
import re

global_res_text = 0
previous_element = 0


# Video-Thread
def video_thread( video, line_color, total_frames):
    
    plt.gray()

    #video, line_color, total_frames = user_input()
    print(total_frames)

    # declare some list and start values which are needed
    save_cnts = 0
    wait = 0

    # init class/values for while loop
    direct = FindDirection()

    while video.isOpened():
        # Read a single frame
        ret, frame = video.read()
        if not ret:
            print("Error load frame")
            break
        
        #Create a Frame Object
        frame = FrameObject(frame)
        img = frame.img

        # Create Segmemtation Object  
        seg = Segmentation(frame, line_color)
        img_cont = seg.get_orientation_lines()

        frame.build_center_line(img_cont)
        img = frame.make_block_over_center_line()
        
        # Get Values from FrameObject to Direction Object
        direct.wait_for_complete_contour(img)
        direct.get_values_from_frame_object(frame)
        direct.find_nearest_line(img_cont)
        direct.check_where_to_go()
        res_text = direct.smooth_output()
        global global_res_text 
        global_res_text= res_text
        #check_last_direction_changed(res_text)
        frame.text_in_frame(res_text)
        #print(res_text)
        frame_show = frame.overlay_segmentation(img_cont)
        
        #direct.add_one_counter()
        cv2.imshow('Processed',frame_show)

        # Check for key press to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        if video.get(cv2.CAP_PROP_POS_FRAMES) == total_frames:
            break
    # Release the video objects and close the windows
    video.release()
    cv2.destroyAllWindows()


# Audio-Thread
def audio_thread():

    global global_res_text
    global previous_element

    while video.isOpened():
        # Read a single frame
        ret, frame = video.read()
        if not ret:
            print("Error load frame")
            break
        
        # Überprüfen, ob sich das letzte Element geändert hat
        if global_res_text != previous_element:
            previous_element = global_res_text
            #print("audio_txt", previous_element)
            audio_output(previous_element)            #play_audio(previous_element)
        #else:
            #print("prev_txt", previous_element)
        #time.sleep(0.1)

     # Check for key press to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        if video.get(cv2.CAP_PROP_POS_FRAMES) == total_frames:
            break
    # Release the video objects and close the windows
    video.release()
    cv2.destroyAllWindows()
 
video, line_color, total_frames = user_input()

# Threads starten
video_thread = threading.Thread(target=video_thread, args=(video, line_color, total_frames))
audio_thread = threading.Thread(target=audio_thread)

video_thread.start()
audio_thread.start()

video_thread.join()
audio_thread.join()
# Out:
# You did a great Job!
# 2329
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
# zero division error
